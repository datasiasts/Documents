# %% [markdown]
# ![google%20forms%20template.png](attachment:google%20forms%20template.png)

# %% [markdown]
# <h1 style="color:#6f0ab6"><center>Python from Basics to OOP</center></h1>

# %% [markdown]
# Stay connected!!!\
# **Facebook:**\
# https://www.facebook.com/profile.php?id=100086216576997 \
# **YouTube:** \
# https://www.youtube.com/channel/UCNHweLJ7GlfLWjfF1rZbU8Q

# %% [markdown]
# <h1 style="color:#4ab2ef">Output</h1>

# %% [markdown]
# <ul><li><b>print() function</b></li></ul>

# %%
print("Datasiasts")
print(2)
# Out:
# Datasiasts
# 2

# %%
print("hello")
print("hello")
# Out:
# hello
# hello

# %%
print("hello",end="\n")
print("hello")
# Out:
# hello
# hello

# %% [markdown]
# <ul><li><b>string formating</b></li></ul>

# %%
name="achraf"
age=20

#using %
print("Hello %s,you are %d years old"%(name,age))

#using .format()
print("Hello {},you are {} years old".format(name,age))

#using f-string
print(f"Hello {name},you are {age} years old")
# Out:
# Hello achraf,you are 20 years old
# Hello achraf,you are 20 years old
# Hello achraf,you are 20 years old

# %% [markdown]
# bonus 1:

# %%
number1=157.3345667
print(f"number1 = {round(number1,4)}")
# Out:
# number1 = 157.3346

# %% [markdown]
# bonus 2:

# %%
name = "achraf"
string1 = f"hello {name}"
string2 = "hello {} again".format(name)
string3 = "hello %s again again" %name
print(string1)
print(string2)
print(string3)
# Out:
# hello achraf
# hello achraf again
# hello achraf again again

# %% [markdown]
# <h1 style="color:#4ab2ef">Input</h1>

# %% [markdown]
# <ul><li><b>input() function</b></li></ul>

# %%
# string1=input()
# print(string1)

# print(type(string1))

# string2=input("Enter a string : ")
# print(string2)

# int1=int(input())
# print(int1)

int2=int(input("Enter an integer : "))
print(int2)

#print(type(s2))
# Out:
# Enter a string : 4
# 4

# %% [markdown]
# bonus 1:

# %%
x,y,z =input("Enter three values : ").split()

print(f"x={x} , y={y} , z={z}")
# Out:
# Enter three values : 1 2 3
# x=1 , y=2 , z=3

# %%
x,y,z =input("Enter three values separated with ',' : ").split(",")

print(f"x={x} , y={y} , z={z}")
# Out:
# Enter three values separated with ',' : 1,2,3
# x=1 , y=2 , z=3

# %%
L=input("Enter multiple values : ").split()

print(L)
# Out:
# Enter multiple values : 1 3 5 6 7
# ['1', '3', '5', '6', '7']

# %% [markdown]
# <h1 style="color:#4ab2ef">Conditionals</h1>

# %%
x=2
if x>=0 :
    print(f"{x} is positive")
else :
    print(f"{x} is negative")
# Out:
# 2 is positive

# %%
x=1.5
if x>=2 :
    print(f"{x} is greater than 2")
elif x>=1 :
    print(f"{x} is between 1 and 2")
elif x>=0 :
    print(f"{x} is between 0 and 1")
else :
    print(f"{x} is negative")
# Out:
# 1.5 is between 1 and 2

# %%
a=1
b=2
# if a==1 and b==2:
#     print("iwa mbrouk")
# if a==1 or b==3:
#     print("iwa mbrouk2")
if not a==2:
    print("iwa mbrouk3")

# %% [markdown]
# <h1 style="color:#4ab2ef">Loops</h1>

# %% [markdown]
# - #### for loop

# %%
for i in range(5):
    print(i,end=" ")
# Out:
# 0 1 2 3 4

# %%
List=["said","sabir", 2 ]
for i in List:
    print(i,end=" ")
# Out:
# said sabir 2

# %% [markdown]
# - #### while loop

# %%
number=int(input("input a positive number : "))
while number<0 :
    number=int(input("input a positive number : "))
print(number)
# Out:
# input a positive number : -2
# input a positive number : -3
# input a positive number : -6
# input a positive number : 2
# 2

# %% [markdown]
# - #### continue

# %%
string1 ='Datasiast'
for i in string1 :
    if i == 'a':
        continue
    print(i)
# Out:
# D
# t
# s
# i
# s
# t

# %% [markdown]
# - #### break

# %%
string1 ='Datasiast'
for i in string1:
    if i == 't':
        break
    print(i)
# Out:
# D
# a

# %% [markdown]
# <h1 style="color:#4ab2ef">Data types</h1>

# %% [markdown]
# <ul><li><b>Integer</b></li></ul>

# %%
int1=-1
print(int1)
# print(type(int1))
# Out:
# -1
# <class 'int'>

# %% [markdown]
# <ul><li><b>Float</b></li></ul>

# %%
float1=22/7
print(float1)
print(type(float1))
# Out:
# 3.142857142857143
# <class 'float'>

# %% [markdown]
# <ul><li><b>Boolean</b></li></ul>

# %%
T=True
F=False
print(T)
print(F)
# Out:
# True
# False

# %% [markdown]
# <ul><li><b>String</b></li></ul>

# %%
phrase = 'Data not found'
phrase2 = "Data not found"
print(phrase[0]) # returns the first character
print(phrase[-1]) # returns the first character from the end
print(phrase[-3]) # returns the sixth character from the end
# Out:
# D
# d
# u

# %%
print(phrase.upper()) # returns an uppercase version of phrase
print(phrase.lower()) # returns an lowercase version of phrase
print(phrase.title()) # returns a new version of phrase with first letter of every word capitalized
print(phrase.replace('a', 'b')) # returns a new version of phrase where all 'a's are replaced with 'b's
print("----------")
print(phrase) #to check if the original string has been changed
print("----------")
print(phrase.find("a")) # returns the index of the first occurrence of "a"
# Out:
# DATA NOT FOUND
# data not found
# Data Not Found
# Dbtb not found
# ----------
# Data not found
# ----------
# 1

# %% [markdown]
# <ul><li><b>Lists</b></li></ul>

# %%
List = [50, 70, 30, 20, 90, 10, 40]
print(List)
List2 = [50, "sabir", 30, 5.8, 90, 10, 40]
print(List2)
# Out:
# [50, 70, 30, 20, 90, 10, 40]
# [50, 'sabir', 30, 5.8, 90, 10, 40]

# %%
print(List[3]) #access
List[3]=5 #modify
print(List) #check
# Out:
# 20
# [50, 70, 30, 5, 90, 10, 40]

# %% [markdown]
# bonus 1: check if an element is in the list

# %%
x=50
if x in List :
    print(f"{x} is in the list ")
else:
    print(f"{x} is not in the list ")
# Out:
# 50 is in the list

# %% [markdown]
# bonus 2: slicing

# %% [markdown]
# form : List_name[start : end : step]

# %%
print(List[::])#taking copy of the list
print(List[::2])
print(List[4::])
print("----------")
print(List[::-1])#inverse a list
print(List[4:2:-1])
print("----------")
print(List)#to check if the original string has been changed
# Out:
# [50, 70, 30, 5, 90, 10, 40]
# [50, 30, 90, 40]
# [90, 10, 40]
# ----------
# [40, 10, 90, 5, 30, 70, 50]
# [90, 5]
# ----------
# [50, 70, 30, 5, 90, 10, 40]

# %% [markdown]
# note : the slicing concept works also with strings

# %% [markdown]
# bonus 3: list comprehension

# %%
List=[ 2*x for x in range(9)]
print(List)
# Out:
# [0, 2, 4, 6, 8, 10, 12, 14, 16]

# %%
List=[ 2*x for x in range(9) if x%3==0]
print(List)
# Out:
# [0, 6, 12]

# %% [markdown]
# <ul><li><b>Sets</b></li></ul>

# %% [markdown]
# A set is a collection of **unindexed** and **unorderd** elements ,not allowing **duplicates**

# %%
#usage
set1=set([1,2,3])
print(set1)

set2={3,4,5}
print(set2)
# Out:
# {1, 2, 3}
# {3, 4, 5}

# %%
#unordered
set1={"hello","hi"}
for i in set1 :
    print(i)
# Out:
# hello
# hi

# %%
#unindexed
print(set1[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1660\554774743.py in <module>
#       1 #unindexed
# ----> 2 print(set1[0])
#
# TypeError: 'set' object is not subscriptable

# %%
#removing duplicates
listWithDuplicates=[1,2,8,7,1,2,5]
print("listWithDuplicates =",listWithDuplicates)

listToSet=set(listWithDuplicates)
print("listToSet =",listToSet)

cleanedList=list(listToSet)
print("clenedList =",cleanedList)
# Out:
# listWithDuplicates = [1, 2, 8, 7, 1, 2, 5]
# listToSet = {1, 2, 5, 7, 8}
# clenedList = [1, 2, 5, 7, 8]

# %%
#basic functions
setA={2,4}
setB={2,3,5}

setA.add(5)
print(setA)

setA.remove(5)
print(setA)

print(setA.intersection(setB))
print(setA.union(setB))
print(setA.difference(setB))
# Out:
# {2, 4, 5}
# {2, 4}
# {2}
# {2, 3, 4, 5}
# {4}

# %% [markdown]
# <ul><li><b>Tuples</b></li></ul>

# %% [markdown]
# A tuple is a collection which is **ordered** and **unchangeable**.

# %%
#usage
Tuple1 = (50, 70, 30, 20, 90, 10, 40)
print(Tuple1)
Tuple2 = (50, "sabir", 30, 5.8, 90, 10, 40)
print(Tuple2)
# Out:
# (50, 70, 30, 20, 90, 10, 40)
# (50, 'sabir', 30, 5.8, 90, 10, 40)

# %%
#unchangeable
print(Tuple1[3]) #access
#Tuple1[3]=5 #testing modifying
# print(Tuple1) #check
# Out:
# 20

# %%
#ordered
Tuple1=(1,2,3)
for i in Tuple1 :
    print(i)
# Out:
# 1
# 2
# 3

# %%
#slicing
print(Tuple1[::2])
# Out:
# (1, 3)

# %% [markdown]
# note : the slicing concept works also with tuples

# %% [markdown]
# bonus :joining tuples

# %%
#join
Tuple1=(1,2)
Tuple2=(3,2)
Tuple3=Tuple1+Tuple2
print(Tuple3)
print(Tuple1)
# Out:
# (1, 2, 3, 2)
# (1, 2)

# %% [markdown]
# <ul><li><b>Dictionaries</b></li></ul>

# %% [markdown]
# form : Dict_name{ key1 :value1 ,key2 :value2 }

# %%
Dictionary1={"name":"sabir","age":6}
print(Dictionary1)
Dictionary2={"first name":"sabir","second name":"man3rf"}
print(Dictionary2)
Dictionary3={"name":"sabir",
        "age":6}
print(Dictionary3)
# Out:
# {'name': 'sabir', 'age': 6}
# {'first name': 'sabir', 'second name': 'man3rf'}
# {'name': 'sabir', 'age': 6}

# %%
print(Dictionary1.keys())
print(Dictionary1.values())

for element in Dictionary1.values():
    print(element)
# Out:
# dict_keys(['name', 'age'])
# dict_values(['sabir', 6])
# sabir
# 6

# %% [markdown]
# <ul><li><b>Mutable vs Immutable</b></li></ul>

# %% [markdown]
# **Mutable** : can be changed (Lists ,dictionaries ...)\
# **Immutable** : can not be changed (Numbers ,Strings,Tuples ...)

# %%
#test1 
list1=[5,6]
print(list1,":",id(list1))
list1.append(7)
print(list1,":",id(list1))
# Out:
# [5, 6] : 3100147990016
# [5, 6, 7] : 3100147990016

# %%
#test2
string1="hello"
print(string1,":",id(string1))
string1=string1+" Club Data"
print(string1,":",id(string1))
# Out:
# hello : 3100109817776
# hello Club Data : 3100148531760

# %%
#test3
int1=4
print(int1,":",id(int1))
int1=5
print(int1,":",id(int1))
# Out:
# 4 : 3100027742608
# 5 : 3100027742640

# %% [markdown]
# <h1 style="color:#4ab2ef">Functions</h1>

# %%
def welcoming():
    print("hello guys")
welcoming()
# Out:
# hello guys

# %%
def showInfo(name,age,state="student"):#default value of state
    print(f"hello {name} , you are {age} years old , you are {state}")

showInfo("sabir",6)
showInfo("sabir",6,"software engineer")
# Out:
# hello sabir , you are 6 years old , you are student
# hello sabir , you are 6 years old , you are software engineer

# %% [markdown]
# <ul><li><b>local vs global</b></li></ul>

# %%
#seuil is global
#mark is local

seuil=12
def acceptedOrNot(mark):
    if mark >seuil:
        print("accepted")
    else:
        print("not accepted")

acceptedOrNot(13)
print(mark)
# Out:
# accepted
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1660\2422232500.py in <module>
#      10
#      11 acceptedOrNot(13)
# ---> 12 print(mark)
#
# NameError: name 'mark' is not defined

# %%
seuil=10
def modifySeuil():
    global seuil
    seuil=12

modifySeuil()

print(seuil)
# Out:
# 12

# %% [markdown]
# <ul><li><b>print vs return</b></li></ul>

# %%
def factorialReturned(num):
    p=1
    for i in range(1,num+1):
        p=p*i
    
    return p

x=factorialReturned(3)
print(x)
# Out:
# 6

# %%
def factorialPrinted(num):
    p=1
    for i in range(1,num+1):
        p=p*i
    
    print(p)
    return p

x=factorialPrinted(3)
print(x)
# Out:
# 6
# 6

# %% [markdown]
# <h1 style="color:#4ab2ef">OOP</h1>

# %% [markdown]
# <ul><li><b>Concept</b></li></ul>

# %% [markdown]
# ![ENSA%20class-3.png](attachment:ENSA%20class-3.png)

# %% [markdown]
# <ul><li><b>Class</b></li></ul>

# %%
class Class_name:
    def __init__(self,attribute1,attribute2): 
        self.attribute1=attribute1
        self.attribute2=attribute2
    
    def show_info(self,param):
        print(f"value of attribute1 is {self.attribute1} and value of attribute2 is {self.attribute2}")
        print(f"value of parameter is {param}")

# %% [markdown]
# <ul><li><b>Object</b></li></ul>

# %%
object1=Class_name("string",6)
print(object1.attribute1)
print(object1.attribute2)
object1.show_info("argument")
# Out:
# string
# 6
# value of attribute1 is string and value of attribute2 is 6
# value of parameter is argument

# %% [markdown]
# <ul><li><b>Constructor</b></li></ul>

# %%
class Class_name:
    def __init__(self,attribut1,attribut2):
        self.attribut1=attribut1
        self.attribut2=attribut2
        print("object created")

C=Class_name("string",6)
# Out:
# object created

# %% [markdown]
# **Example**

# %%
class ENSA:
    def __init__(self,name,city,capacity):
        self.name=name
        self.city=city
        self.capacity=capacity
    
    def engineering(self):
        print(f"{self.capacity} student are joining {self.name} every year ")

# %%
ENSAH=ENSA("ENSAH","Hoceima",280)
ENSAT=ENSA("ENSAT","Tanger",340)
ENSAK=ENSA("ENSAK","Kenitra",300)

# %%
print(ENSAH.capacity)
print(ENSAK.city)
ENSAT.engineering()
ENSAH.engineering()
# Out:
# 280
# Kenitra
# 340 student are joining ENSAT every year
# 280 student are joining ENSAH every year

# %% [markdown]
# <ul><li><b>Static attributes</b></li></ul>

# %% [markdown]
# Humans count example

# %%
class Human:
    count=0 #class/static attribute
    
    def __init__(self,name):
        self.name=name #object attribute
        Human.count+=1

human1=Human("sabir")
print(Human.count)
human2=Human("amine")
print(Human.count)
print(human1.count)
# Out:
# 1
# 2
# 2

# %%
human1.count=5
print(human1.count)
print(Human.count)
# Out:
# 5
# 2

# %% [markdown]
# <ul><li><b>Static methodes</b></li></ul>

# %% [markdown]
# Student and administration example

# %%
class Student:
    count=0 #class/static attribute
    def __init__(self,name):
        self.name=name #object attribute
        Student.count+=1
    
    @staticmethod
    def showInfo():# static methode
        print(f"number of students is {Student.count}")

Student.showInfo()
student1=Student("sabir")
Student.showInfo()
student1.showInfo()
# Out:
# number of students is 0
# number of students is 1
# number of students is 1

# %% [markdown]
# <ul><li><b>Operator overloading</b></li></ul>

# %%
class Assir:
    def __init__(self,tofah,banane):
        self.tofah=tofah
        self.banane=banane
    
    def __add__(self,another_one):
        return Assir( self.tofah + another_one.tofah , self.banane + another_one.banane)

assir1=Assir(2,9)
assir2=Assir(4,3)
assir3=assir1+assir2
print(f"number of tofah in assir3 = {assir3.tofah}")
print(f"number of banane in assir3 = {assir3.banane}")
# Out:
# number of tofah in assir3 = 6
# number of banane in assir3 = 12

# %% [markdown]
# for more you can check : https://www.geeksforgeeks.org/operator-overloading-in-python/

# %% [markdown]
# <ul><li><b>Printing objects</b></li></ul>

# %%
class Assir:
    def __init__(self,tofah,banane):
        self.tofah=tofah
        self.banane=banane
    
    def __add__(self,another_one):
        return Assir(self.tofah+another_one.tofah,self.banane+another_one.banane)
    
    def __str__(self):
        return f"there is {self.tofah} tofahs and {self.banane} bananes"
    
assir=Assir(5,3)
print(assir)
# Out:
# there is 5 tofahs and 3 bananes

# %% [markdown]
# <h1 style="color:#4ab2ef">Inheritence</h1>

# %%
class Parent:
    def __init__(self,attribute1,attribute2,name):
        self.attribute1=attribute1
        self.attribute2=attribute2
        self.name=name
    
    def parentFunction(self):
        print(f"I am {self.name} and this function is from the parent class")
        
        
class Child(Parent):
    def __init__(self,attribute1,attribute2,name,childAttribute):
        super().__init__(attribute1,attribute2,name)
        
        self.childAttribute=childAttribute
    
    def childFunction(self):
        print(f"I am {self.name} and this function is from the child class")
        
        
parent1=Parent(2,3,"father")
child1=Child(4,5,"child","extra atribute")
        
parent1.parentFunction()#executing a parent function from a parent object
child1.parentFunction()#executing a parent function from a child object
child1.childFunction()#executing a child fuction from a child object
# Out:
# I am father and this function is from the parent class
# I am child and this function is from the parent class
# I am child and this function is from the child class

# %% [markdown]
# #### exemple

# %%
class Hayawan :
    def __init__(self,name,weight):
        self.name=name
        self.weight=weight
    
    def eat(self):
        print(f"{self.name} is eating")

class Cat(Hayawan):
    def __init__(self,name,weight,owner):
        super().__init__(name,weight)
        self.owner=owner
    
    def miaw(self):
        print("miaw miaw miaw")
    
class Shark(Hayawan):
    def __init__(self,name,weight):
        super().__init__(name,weight)
    
    def swim(self):
        print("swiiiiming")

# %%
hayawan1=Hayawan("far",5)
hayawan1.eat()
# Out:
# far is eating

# %%
cat1=Cat("lmech",10,"Anas")
cat1.eat()
cat1.miaw()
# Out:
# lmech is eating
# miaw miaw miaw

# %%
shark1=Shark("l9irch",50)
shark1.eat()
shark1.swim()
# Out:
# l9irch is eating
# swiiiiming

# %% [markdown]
# <h1 style="color:#4ab2ef">Polymorphisme</h1>

# %%
class Person:
    def __init__(self,nom):
        self.nom=nom

    def affiche(self):
        print("I am a person")

class Student(Person):
    def __init__(self,nom,cne):
        super().__init__(nom)  
        self.cne=cne

    def affiche(self):
        print("I am a student")

class Teacher(Person):
    def __init__(self,nom,ppr):
        super().__init__(nom)  
        self.ppr=ppr

    def affiche(self):
        print("I am a teacher")

# %%
parent1=Person("sabir")
student1=Student("amine","p110144139")
teacher1=Teacher("mohamed",444444)

# %% [markdown]
# Let's notice the behavior of the **affiche function**

# %%
parent1.affiche()
# Out:
# I am a person

# %%
student1.affiche()
# Out:
# I am a student

# %%
teacher1.affiche()
# Out:
# I am a teacher

# %% [markdown]
# <h1 style="color:#4ab2ef">Encapsulation</h1>

# %% [markdown]
# This is encapsulation 👇🏻

# %%
class Class_name:
    def __init__(self,attribute1,attribute2):
        self.attribute1=attribute1
        self.attribute2=attribute2
    
    def function1(self):
        print("Doing something")
    
    def function2(self):
        print("Doing something else")

# %% [markdown]
# <h4>Access modifiers</h4>

# %% [markdown]
# <ul>
# <li><b>public</b> : accessible from everywhere</li>
# <li><b>_protected</b> : accessible from the class itself and it's children</li>
# <li><b>__private</b> : accessible just from the class</li>
# </ul>

# %%
class Parent:
    def __init__(self):
        self.publicAttribute="this is public"
        self._protectedAttribute="this is protected"
        self.__privateAttribute="this is private"
    
        
    def showPublic(self):
        print(f"printing the public attribute : {self.publicAttribute}")
    
    def showProtected(self):
        print(f"printing the protected attribute : {self._protectedAttribute}")
        
    def showPrivate(self):
        print(f"printing the private attribute : {self.__privateAttribute}")
        

class Child(Parent):
    def __init__(self):
        super().__init__()
    
    def printPublic(self):
        print(f"this a public attribute called from child : {self.publicAttribute}")
    def printProtected(self):
        print(f"this a protected attribute called from child : {self._protectedAttribute}")
    def printPrivate(self):
        print(f"this a private attribute called from child : {self.__privateAttribute}")

# %%
parent1=Parent()
child1=Child()

# %% [markdown]
# Accessing the **public** attributes

# %%
print(parent1.publicAttribute)
parent1.showPublic()
child1.printPublic()
# Out:
# this is public
# printing the public attribute : this is public
# this a public attribute called from child : this is public

# %% [markdown]
# Accessing the **private** attributes

# %%
parent1.showPrivate()
# print(parent1.__privateAttribute)
child1.printPrivate()
# Out:
# printing the private attribute : this is private
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9652\500738171.py in <module>
#       1 parent1.showPrivate()
#       2 # print(parent1.__privateAttribute)
# ----> 3 child1.printPrivate()
#
# ~\AppData\Local\Temp\ipykernel_9652\96072027.py in printPrivate(self)
#      25         print(f"this a protected attribute called from child : {self._protectedAttribute}")
#      26     def printPrivate(self):
# ---> 27         print(f"this a private attribute called from child : {self.__privateAttribute}")
#      28
#
# AttributeError: 'Child' object has no attribute '_Child__privateAttribute'

# %% [markdown]
# Accessing the **protected** attributes

# %% [markdown]
# Guess the output

# %%
parent1.showProtected()
#print(parent1._protectedAttribute)
child1.printProtected()
# Out:
# printing the protected attribute : this is protected
# this is protected
# this a protected attribute called from child : this is protected

# %% [markdown]
# Let's do another test

# %%
print(parent1._Parent__privateAttribute)
# Out:
# this is private

# %% [markdown]
# <h4>Getters && Setters</h4>

# %% [markdown]
# Getter : to control how the user gets the value\
# Setter : to control how the user sets the value

# %%
class Parent:
    def __init__(self):
        self.__fullName=None
        
    def setFullName(self,name):
        self.__fullName=name.replace(" ","_")
    
    def getFullName(self):
        if self.__fullName==None:
            return "no name set"
        return self.__fullName.replace("_"," ")
    
    def printRealFullName(self):
        return self.__fullName

# %%
parent1=Parent()
parent1.setFullName("yassine boonooooo")
print(parent1.getFullName())
print(parent1.printRealFullName())
# Out:
# yassine boonooooo
# yassine_boonooooo
